# %% [markdown]
# ### Obtaining Pricing Data
#
# https://www.quantstart.com/articles/Securities-Master-Database-with-MySQL-and-Python/
#
# In order to obtain the historical data for the current S&P500 constituents, we must first query the database for the list of all the symbols. Once the list of symbols (along with the symbol IDs) have been returned, it is possible to call the Yahoo Finance API and download the historical pricing data for each symbol. Once we have each symbol we can insert the data into the database in turn. Here's the Python code to carry this out:

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import datetime as dt
import MySQLdb as mdb # https://github.com/PyMySQL/mysqlclient-python/blob/master/doc/user_guide.rst#cursor-objects
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import sqlalchemy as sql
import time
import random

get_quandl_data=False
get_yahoo_data=False

# Obtain a database connection to the MySQL instance
db_host = 'localhost'
db_user = 'sec_user'
db_pass = 'securities'
db_name = 'securities_master'
unix_socket = "/var/run/mysqld/mysqld.sock"
dbconn = mdb.connect(host="localhost",unix_socket=unix_socket,user="sec_user",passwd="securities",db="securities_master")

#connect_string = 'mysql://root:southpark@localhost/test'
connect_string = 'mysql://sec_user:securities@localhost/securities_master?unix_socket=/var/run/mysqld/mysqld.sock'
sql_engine = sql.create_engine(connect_string) #Setup a persistent connection


def obtain_list_of_db_tickers():
  """Obtains a list of the ticker symbols in the database."""
  cur = dbconn.cursor()
  cur.execute("SELECT id, ticker FROM symbol")
  data = cur.fetchall()
  return [(d[0], d[1]) for d in data]

'''def get_daily_historic_data_yahoo_old(ticker,
                      start_date=(2000,1,1),
                      end_date=datetime.date.today().timetuple()[0:3]):
    """Obtains data from Yahoo Finance returns and a list of tuples.

  ticker: Yahoo Finance ticker symbol, e.g. "GOOG" for Google, Inc.
  start_date: Start date in (YYYY, M, D) format
  end_date: End date in (YYYY, M, D) format"""

    # Construct the Yahoo URL with the correct integer query parameters
    # for start and end dates. Note that some parameters are zero-based!
    yahoo_url = "http://ichart.finance.yahoo.com/table.csv?s=%s&a=%s&b=%s&c=%s&d=%s&e=%s&f=%s" % \
      (ticker, start_date[1] - 1, start_date[2], start_date[0], end_date[1] - 1, end_date[2], end_date[0])
    print('URL for %s: %s' % (ticker,yahoo_url))
    # Try connecting to Yahoo Finance and obtaining the data
    # On failure, print an error message.
    try:
        yf_data = urllib3.urlopen(yahoo_url).readlines()[1:] # Ignore the header
        resp = requests.get('yahoo_url')
        soup = bs.BeautifulSoup(resp.text, 'lxml')
        table = soup.find('table', {'class': 'wikitable sortable'})
        
        prices = []
        for y in yf_data:
          p = y.strip().split(',')
          prices.append( (datetime.datetime.strptime(p[0], '%Y-%m-%d'),
                  p[1], p[2], p[3], p[4], p[5], p[6]) )
    except (OSError, RuntimeError, TypeError, NameError):
        print("Could not download Yahoo data: %s\n" % RuntimeError)
    return prices
'''

def get_daily_historic_data_yahoo(ticker, start_date=("2000,1,1"), end_date=dt.date.today()):#.timetuple()[0:3]):
    from pandas_datareader import data as pdr
    import fix_yahoo_finance
    start_date = dt.datetime.strptime(start_date, "%Y,%m,%d")
    try:
        #Here's what we need: aapl = pdr.get_data_yahoo('AAPL', start=datetime.datetime(2006, 10, 1), end=datetime.datetime(2012, 1, 1))
        stock_df = pdr.get_data_yahoo(ticker, start=start_date, end=end_date)
        #aapl.to_csv('./data/aapl_ohlc.csv') #Export data as csv
        return(stock_df)
    except (OSError, RuntimeError, TypeError, NameError, KeyError) as e:
        print("Could not download Yahoo data: %s\n" % e)
        return(None)

# %%
#yf_data.tail()

# %% [markdown]
# Note that there are certainly ways we can optimise this procedure. If we make use of the Python ScraPy library, for instance, we would gain high concurrency from the downloads, as ScraPy is built on the event-driven Twisted framework. At the moment each download will be carried out sequentially.

# %% [markdown]
# ### Table Details for daily_price:
# CREATE TABLE daily_price ( id int AUTO_INCREMENT, data_vendor_id int, symbol_id int, price_date datetime, created_date datetime, last_updated_date datetime, open_price decimal(19,4), high_price decimal(19,4), low_price decimal(19,4), close_price decimal(19,4), adj_close_price decimal(19,4), volume bigint, PRIMARY KEY (id), KEY index_data_vendor_id (data_vendor_id), KEY index_synbol_id (symbol_id) ) ENGINE=InnoDB AUTO_INCREMENT=1 DEFAULT CHARSET=utf8;

# %%
def insert_daily_data_into_db(data_vendor_id, symbol_id, daily_data):
    #daily_price columns: id, data_vendor_id, symbol_id, price_date, created_date, last_updated_date, open_price, high_price, low_price, close_price, adj_close_price, volume
    now = dt.datetime.utcnow()
    daily_data['data_vendor_id'] = data_vendor_id
    daily_data['symbol_id'] = symbol_id
    daily_data['created_date'] = now
    daily_data['last_updated_date'] = now
    daily_data.to_sql(name='daily_price', con=sql_engine, if_exists = 'append', index=True) #if_exists applies to table. Options are 'fail', 'append', 'replace'
    #print(daily_data.head())

# %%
if __name__ == "__main__":
  # Loop over the tickers and insert the daily historical
  # data into the database
  tickers = obtain_list_of_db_tickers()
  for t in tickers[:]:
    print("Getting data for %s" % (t[1]))
    yf_data = get_daily_historic_data_yahoo(t[1]) #Passes ticker symbol
    #print(type(yf_data))
    #yf_data = get_daily_historic_data_yahoo('BRK.B') #Passes ticker symbol
    if type(yf_data) == pd.core.frame.DataFrame:
      print("Adding data for %s" % (t[1]))
      insert_daily_data_into_db('1', t[0], yf_data)
    sleeptime = random.randint(1, 5)
    print("Sleeping for %s" % sleeptime); time.sleep(sleeptime)
# Out:
# Getting data for MMM
# Adding data for MMM
# Sleeping for 4
# Getting data for ABT
# Adding data for ABT
# Sleeping for 1
# Getting data for ABBV
# Adding data for ABBV
# Sleeping for 3
# Getting data for ABMD
# Adding data for ABMD
# Sleeping for 3
# Getting data for ACN
# Adding data for ACN
# Sleeping for 4
# Getting data for ATVI
# Adding data for ATVI
# Sleeping for 3
# Getting data for ADBE
# Adding data for ADBE
# Sleeping for 1
# Getting data for AMD
# Adding data for AMD
# Sleeping for 2
# Getting data for AAP
# Adding data for AAP
# Sleeping for 3
# Getting data for AES
# Adding data for AES
# Sleeping for 5
# Getting data for AMG
# Adding data for AMG
# Sleeping for 3
# Getting data for AFL
# Adding data for AFL
# Sleeping for 2
# Getting data for A
# Adding data for A
# Sleeping for 5
# Getting data for APD
# Adding data for APD
# Sleeping for 2
# Getting data for AKAM
# Adding data for AKAM
# Sleeping for 4
# Getting data for ALK
# Adding data for ALK
# Sleeping for 2
# Getting data for ALB
# Adding data for ALB
# Sleeping for 4
# Getting data for ARE
# Adding data for ARE
# Sleeping for 5
# Getting data for ALXN
# Adding data for ALXN
# Sleeping for 4
# Getting data for ALGN
# Adding data for ALGN
# Sleeping for 1
# Getting data for ALLE
# Adding data for ALLE
# Sleeping for 2
# Getting data for AGN
# Adding data for AGN
# Sleeping for 1
# Getting data for ADS
# Adding data for ADS
# Sleeping for 3
# Getting data for LNT
# Adding data for LNT
# Sleeping for 1
# Getting data for ALL
# Adding data for ALL
# Sleeping for 4
# Getting data for GOOGL
# Adding data for GOOGL
# Sleeping for 2
# Getting data for GOOG
# Adding data for GOOG
# Sleeping for 3
# Getting data for MO
# Adding data for MO
# Sleeping for 2
# Getting data for AMZN
# Adding data for AMZN
# Sleeping for 5
# Getting data for AMCR
# Adding data for AMCR
# Sleeping for 2
# Getting data for AEE
# Adding data for AEE
# Sleeping for 5
# Getting data for AAL
# Adding data for AAL
# Sleeping for 1
# Getting data for AEP
# Adding data for AEP
# Sleeping for 2
# Getting data for AXP
# Adding data for AXP
# Sleeping for 2
# Getting data for AIG
# Adding data for AIG
# Sleeping for 5
# Getting data for AMT
# Adding data for AMT
# Sleeping for 3
# Getting data for AWK
# Adding data for AWK
# Sleeping for 4
# Getting data for AMP
# Adding data for AMP
# Sleeping for 4
# Getting data for ABC
# Adding data for ABC
# Sleeping for 3
# Getting data for AME
# Adding data for AME
# Sleeping for 1
# Getting data for AMGN
# Adding data for AMGN
# Sleeping for 4
# Getting data for APH
# Adding data for APH
# Sleeping for 5
# Getting data for ADI
# Adding data for ADI
# Sleeping for 5
# Getting data for ANSS
# Adding data for ANSS
# Sleeping for 1
# Getting data for ANTM
# Adding data for ANTM
# Sleeping for 4
# Getting data for AON
# Adding data for AON
# Sleeping for 3
# Getting data for AOS
# Adding data for AOS
# Sleeping for 1
# Getting data for APA
# Adding data for APA
# Sleeping for 3
# Getting data for AIV
# Adding data for AIV
# Sleeping for 3
# Getting data for AAPL
# Adding data for AAPL
# Sleeping for 2
# Getting data for AMAT
# Adding data for AMAT
# Sleeping for 4
# Getting data for APTV
# Adding data for APTV
# Sleeping for 3
# Getting data for ADM
# Adding data for ADM
# Sleeping for 2
# Getting data for ARNC
# Adding data for ARNC
# Sleeping for 4
# Getting data for ANET
# Adding data for ANET
# Sleeping for 3
# Getting data for AJG
# Adding data for AJG
# Sleeping for 2
# Getting data for AIZ
# Adding data for AIZ
# Sleeping for 3
# Getting data for ATO
# Adding data for ATO
# Sleeping for 5
# Getting data for T
# Adding data for T
# Sleeping for 1
# Getting data for ADSK
# Adding data for ADSK
# Sleeping for 5
# Getting data for ADP
# Adding data for ADP
# Sleeping for 2
# Getting data for AZO
# Adding data for AZO
# Sleeping for 4
# Getting data for AVB
# Adding data for AVB
# Sleeping for 2
# Getting data for AVY
# Adding data for AVY
# Sleeping for 4
# Getting data for BHGE
# Adding data for BHGE
# Sleeping for 1
# Getting data for BLL
# Adding data for BLL
# Sleeping for 2
# Getting data for BAC
# Adding data for BAC
# Sleeping for 4
# Getting data for BK
# Adding data for BK
# Sleeping for 4
# Getting data for BAX
# Adding data for BAX
# Sleeping for 3
# Getting data for BBT
# Adding data for BBT
# Sleeping for 4
# Getting data for BDX
# Adding data for BDX
# Sleeping for 4
# Getting data for BRK.B
# Could not download Yahoo data: 'Date'
#
# Sleeping for 3
# Getting data for BBY
# Adding data for BBY
# Sleeping for 2
# Getting data for BIIB
# Adding data for BIIB
# Sleeping for 2
# Getting data for BLK
# Adding data for BLK
# Sleeping for 3
# Getting data for HRB
# Adding data for HRB
# Sleeping for 4
# Getting data for BA
# Adding data for BA
# Sleeping for 2
# Getting data for BKNG
# Adding data for BKNG
# Sleeping for 4
# Getting data for BWA
# Adding data for BWA
# Sleeping for 4
# Getting data for BXP
# Adding data for BXP
# Sleeping for 5
# Getting data for BSX
# Adding data for BSX
# Sleeping for 3
# Getting data for BMY
# Adding data for BMY
# Sleeping for 4
# Getting data for AVGO
# Adding data for AVGO
# Sleeping for 5
# Getting data for BR
# Adding data for BR
# Sleeping for 1
# Getting data for BF.B
# Could not download Yahoo data: 'Date'
#
# Sleeping for 1
# Getting data for CHRW
# Adding data for CHRW
# Sleeping for 3
# Getting data for COG
# Adding data for COG
# Sleeping for 5
# Getting data for CDNS
# Adding data for CDNS
# Sleeping for 4
# Getting data for CPB
# Adding data for CPB
# Sleeping for 3
# Getting data for COF
# Adding data for COF
# Sleeping for 1
# Getting data for CPRI
# Adding data for CPRI
# Sleeping for 5
# Getting data for CAH
# Adding data for CAH
# Sleeping for 5
# Getting data for KMX
# Adding data for KMX
# Sleeping for 1
# Getting data for CCL
# Adding data for CCL
# Sleeping for 1
# Getting data for CAT
# Adding data for CAT
# Sleeping for 4
# Getting data for CBOE
# Adding data for CBOE
# Sleeping for 3
# Getting data for CBRE
# Adding data for CBRE
# Sleeping for 2
# Getting data for CBS
# Adding data for CBS
# Sleeping for 4
# Getting data for CE
# Adding data for CE
# Sleeping for 2
# Getting data for CNC
# Adding data for CNC
# Sleeping for 3
# Getting data for CNP
# Adding data for CNP
# Sleeping for 4
# Getting data for CTL
# Adding data for CTL
# Sleeping for 3
# Getting data for CERN
# Adding data for CERN
# Sleeping for 4
# Getting data for CF
# Adding data for CF
# Sleeping for 3
# Getting data for SCHW
# Adding data for SCHW
# Sleeping for 5
# Getting data for CHTR
# Adding data for CHTR
# Sleeping for 3
# Getting data for CVX
# Adding data for CVX
# Sleeping for 4
# Getting data for CMG
# Adding data for CMG
# Sleeping for 2
# Getting data for CB
# Adding data for CB
# Sleeping for 1
# Getting data for CHD
# Adding data for CHD
# Sleeping for 2
# Getting data for CI
# Adding data for CI
# Sleeping for 5
# Getting data for XEC
# Adding data for XEC
# Sleeping for 4
# Getting data for CINF
# Adding data for CINF
# Sleeping for 2
# Getting data for CTAS
# Adding data for CTAS
# Sleeping for 4
# Getting data for CSCO
# Adding data for CSCO
# Sleeping for 4
# Getting data for C
# Adding data for C
# Sleeping for 3
# Getting data for CFG
# Adding data for CFG
# Sleeping for 3
# Getting data for CTXS
# Adding data for CTXS
# Sleeping for 2
# Getting data for CLX
# Adding data for CLX
# Sleeping for 1
# Getting data for CME
# Adding data for CME
# Sleeping for 1
# Getting data for CMS
# Adding data for CMS
# Sleeping for 1
# Getting data for KO
# Adding data for KO
# Sleeping for 4
# Getting data for CTSH
# Adding data for CTSH
# Sleeping for 1
# Getting data for CL
# Adding data for CL
# Sleeping for 3
# Getting data for CMCSA
# Adding data for CMCSA
# Sleeping for 1
# Getting data for CMA
# Adding data for CMA
# Sleeping for 5
# Getting data for CAG
# Adding data for CAG
# Sleeping for 3
# Getting data for CXO
# Adding data for CXO
# Sleeping for 1
# Getting data for COP
# Adding data for COP
# Sleeping for 2
# Getting data for ED
# Adding data for ED
# Sleeping for 1
# Getting data for STZ
# Adding data for STZ
# Sleeping for 3
# Getting data for COO
# Adding data for COO
# Sleeping for 2
# Getting data for CPRT
# Adding data for CPRT
# Sleeping for 4
# Getting data for GLW
# Adding data for GLW
# Sleeping for 5
# Getting data for CTVA
# Adding data for CTVA
# Sleeping for 2
# Getting data for COST
# Adding data for COST
# Sleeping for 2
# Getting data for COTY
# Adding data for COTY
# Sleeping for 4
# Getting data for CCI
# Adding data for CCI
# Sleeping for 2
# Getting data for CSX
# Adding data for CSX
# Sleeping for 5
# Getting data for CMI
# Adding data for CMI
# Sleeping for 4
# Getting data for CVS
# Adding data for CVS
# Sleeping for 4
# Getting data for DHI
# Adding data for DHI
# Sleeping for 1
# Getting data for DHR
# Adding data for DHR
# Sleeping for 4
# Getting data for DRI
# Adding data for DRI
# Sleeping for 1
# Getting data for DVA
# Adding data for DVA
# Sleeping for 4
# Getting data for DE
# Adding data for DE
# Sleeping for 3
# Getting data for DAL
# Adding data for DAL
# Sleeping for 4
# Getting data for XRAY
# Adding data for XRAY
# Sleeping for 2
# Getting data for DVN
# Adding data for DVN
# Sleeping for 2
# Getting data for FANG
# Adding data for FANG
# Sleeping for 3
# Getting data for DLR
# Adding data for DLR
# Sleeping for 5
# Getting data for DFS
# Adding data for DFS
# Sleeping for 2
# Getting data for DISCA
# Adding data for DISCA
# Sleeping for 2
# Getting data for DISCK
# Adding data for DISCK
# Sleeping for 3
# Getting data for DISH
# Adding data for DISH
# Sleeping for 3
# Getting data for DG
# Adding data for DG
# Sleeping for 5
# Getting data for DLTR
# Adding data for DLTR
# Sleeping for 4
# Getting data for D
# Adding data for D
# Sleeping for 5
# Getting data for DOV
# Adding data for DOV
# Sleeping for 1
# Getting data for DOW
# Adding data for DOW
# Sleeping for 2
# Getting data for DTE
# Adding data for DTE
# Sleeping for 4
# Getting data for DUK
# Adding data for DUK
# Sleeping for 2
# Getting data for DRE
# Adding data for DRE
# Sleeping for 1
# Getting data for DD
# Adding data for DD
# Sleeping for 1
# Getting data for DXC
# Adding data for DXC
# Sleeping for 4
# Getting data for ETFC
# Adding data for ETFC
# Sleeping for 2
# Getting data for EMN
# Adding data for EMN
# Sleeping for 4
# Getting data for ETN
# Adding data for ETN
# Sleeping for 5
# Getting data for EBAY
# Adding data for EBAY
# Sleeping for 1
# Getting data for ECL
# Adding data for ECL
# Sleeping for 4
# Getting data for EIX
# Adding data for EIX
# Sleeping for 2
# Getting data for EW
# Adding data for EW
# Sleeping for 1
# Getting data for EA
# Adding data for EA
# Sleeping for 4
# Getting data for EMR
# Adding data for EMR
# Sleeping for 1
# Getting data for ETR
# Adding data for ETR
# Sleeping for 2
# Getting data for EOG
# Adding data for EOG
# Sleeping for 2
# Getting data for EFX
# Adding data for EFX
# Sleeping for 5
# Getting data for EQIX
# Adding data for EQIX
# Sleeping for 3
# Getting data for EQR
# Adding data for EQR
# Sleeping for 2
# Getting data for ESS
# Adding data for ESS
# Sleeping for 1
# Getting data for EL
# Adding data for EL
# Sleeping for 1
# Getting data for EVRG
# Adding data for EVRG
# Sleeping for 1
# Getting data for ES
# Adding data for ES
# Sleeping for 2
# Getting data for RE
# Adding data for RE
# Sleeping for 3
# Getting data for EXC
# Adding data for EXC
# Sleeping for 4
# Getting data for EXPE
# Adding data for EXPE
# Sleeping for 2
# Getting data for EXPD
# Adding data for EXPD
# Sleeping for 2
# Getting data for EXR
# Adding data for EXR
# Sleeping for 2
# Getting data for XOM
# Adding data for XOM
# Sleeping for 1
# Getting data for FFIV
# Adding data for FFIV
# Sleeping for 1
# Getting data for FB
# Adding data for FB
# Sleeping for 2
# Getting data for FAST
# Adding data for FAST
# Sleeping for 3
# Getting data for FRT
# Adding data for FRT
# Sleeping for 3
# Getting data for FDX
# Adding data for FDX
# Sleeping for 5
# Getting data for FIS
# Adding data for FIS
# Sleeping for 5
# Getting data for FITB
# Adding data for FITB
# Sleeping for 3
# Getting data for FE
# Adding data for FE
# Sleeping for 4
# Getting data for FRC
# Adding data for FRC
# Sleeping for 2
# Getting data for FLT
# Adding data for FLT
# Sleeping for 2
# Getting data for FLIR
# Adding data for FLIR
# Sleeping for 1
# Getting data for FLS
# Adding data for FLS
# Sleeping for 4
# Getting data for FMC
# Adding data for FMC
# Sleeping for 3
# Getting data for F
# Adding data for F
# Sleeping for 5
# Getting data for FTNT
# Adding data for FTNT
# Sleeping for 1
# Getting data for FTV
# Adding data for FTV
# Sleeping for 5
# Getting data for FBHS
# Adding data for FBHS
# Sleeping for 1
# Getting data for FOXA
# Adding data for FOXA
# Sleeping for 1
# Getting data for FOX
# Adding data for FOX
# Sleeping for 3
# Getting data for BEN
# Adding data for BEN
# Sleeping for 4
# Getting data for FCX
# Adding data for FCX
# Sleeping for 3
# Getting data for GPS
# Adding data for GPS
# Sleeping for 4
# Getting data for GRMN
# Adding data for GRMN
# Sleeping for 4
# Getting data for IT
# Adding data for IT
# Sleeping for 4
# Getting data for GD
# Adding data for GD
# Sleeping for 5
# Getting data for GE
# Adding data for GE
# Sleeping for 4
# Getting data for GIS
# Adding data for GIS
# Sleeping for 2
# Getting data for GM
# Adding data for GM
# Sleeping for 4
# Getting data for GPC
# Adding data for GPC
# Sleeping for 5
# Getting data for GILD
# Adding data for GILD
# Sleeping for 2
# Getting data for GPN
# Adding data for GPN
# Sleeping for 4
# Getting data for GS
# Adding data for GS
# Sleeping for 5
# Getting data for GWW
# Adding data for GWW
# Sleeping for 3
# Getting data for HAL
# Adding data for HAL
# Sleeping for 2
# Getting data for HBI
# Adding data for HBI
# Sleeping for 3
# Getting data for HOG
# Adding data for HOG
# Sleeping for 2
# Getting data for HIG
# Adding data for HIG
# Sleeping for 2
# Getting data for HAS
# Adding data for HAS
# Sleeping for 4
# Getting data for HCA
# Adding data for HCA
# Sleeping for 4
# Getting data for HCP
# Adding data for HCP
# Sleeping for 3
# Getting data for HP
# Adding data for HP
# Sleeping for 4
# Getting data for HSIC
# Adding data for HSIC
# Sleeping for 1
# Getting data for HSY
# Adding data for HSY
# Sleeping for 2
# Getting data for HES
# Adding data for HES
# Sleeping for 2
# Getting data for HPE
# Adding data for HPE
# Sleeping for 3
# Getting data for HLT
# Adding data for HLT
# Sleeping for 5
# Getting data for HFC
# Adding data for HFC
# Sleeping for 1
# Getting data for HOLX
# Adding data for HOLX
# Sleeping for 2
# Getting data for HD
# Adding data for HD
# Sleeping for 4
# Getting data for HON
# Adding data for HON
# Sleeping for 4
# Getting data for HRL
# Adding data for HRL
# Sleeping for 4
# Getting data for HST
# Adding data for HST
# Sleeping for 4
# Getting data for HPQ
# Adding data for HPQ
# Sleeping for 5
# Getting data for HUM
# Adding data for HUM
# Sleeping for 5
# Getting data for HBAN
# Adding data for HBAN
# Sleeping for 5
# Getting data for HII
# Adding data for HII
# Sleeping for 2
# Getting data for IEX
# Adding data for IEX
# Sleeping for 4
# Getting data for IDXX
# Adding data for IDXX
# Sleeping for 2
# Getting data for INFO
# Adding data for INFO
# Sleeping for 2
# Getting data for ITW
# Adding data for ITW
# Sleeping for 2
# Getting data for ILMN
# Adding data for ILMN
# Sleeping for 3
# Getting data for IR
# Adding data for IR
# Sleeping for 2
# Getting data for INTC
# Adding data for INTC
# Sleeping for 4
# Getting data for ICE
# Adding data for ICE
# Sleeping for 3
# Getting data for IBM
# Adding data for IBM
# Sleeping for 2
# Getting data for INCY
# Adding data for INCY
# Sleeping for 4
# Getting data for IP
# Adding data for IP
# Sleeping for 5
# Getting data for IPG
# Adding data for IPG
# Sleeping for 1
# Getting data for IFF
# Adding data for IFF
# Sleeping for 3
# Getting data for INTU
# Adding data for INTU
# Sleeping for 1
# Getting data for ISRG
# Adding data for ISRG
# Sleeping for 4
# Getting data for IVZ
# Adding data for IVZ
# Sleeping for 3
# Getting data for IPGP
# Adding data for IPGP
# Sleeping for 4
# Getting data for IQV
# Adding data for IQV
# Sleeping for 3
# Getting data for IRM
# Adding data for IRM
# Sleeping for 2
# Getting data for JKHY
# Adding data for JKHY
# Sleeping for 5
# Getting data for JEC
# Adding data for JEC
# Sleeping for 3
# Getting data for JBHT
# Adding data for JBHT
# Sleeping for 5
# Getting data for JEF
# Adding data for JEF
# Sleeping for 4
# Getting data for SJM
# Adding data for SJM
# Sleeping for 3
# Getting data for JNJ
# Adding data for JNJ
# Sleeping for 1
# Getting data for JCI
# Adding data for JCI
# Sleeping for 2
# Getting data for JPM
# Adding data for JPM
# Sleeping for 3
# Getting data for JNPR
# Adding data for JNPR
# Sleeping for 3
# Getting data for KSU
# Adding data for KSU
# Sleeping for 2
# Getting data for K
# Adding data for K
# Sleeping for 3
# Getting data for KEY
# Adding data for KEY
# Sleeping for 5
# Getting data for KEYS
# Adding data for KEYS
# Sleeping for 3
# Getting data for KMB
# Adding data for KMB
# Sleeping for 1
# Getting data for KIM
# Adding data for KIM
# Sleeping for 4
# Getting data for KMI
# Adding data for KMI
# Sleeping for 1
# Getting data for KLAC
# Adding data for KLAC
# Sleeping for 3
# Getting data for KSS
# Adding data for KSS
# Sleeping for 4
# Getting data for KHC
# Adding data for KHC
# Sleeping for 1
# Getting data for KR
# Adding data for KR
# Sleeping for 1
# Getting data for LB
# Adding data for LB
# Sleeping for 3
# Getting data for LHX
# Adding data for LHX
# Sleeping for 5
# Getting data for LH
# Adding data for LH
# Sleeping for 2
# Getting data for LRCX
# Adding data for LRCX
# Sleeping for 3
# Getting data for LW
# Adding data for LW
# Sleeping for 4
# Getting data for LEG
# Adding data for LEG
# Sleeping for 3
# Getting data for LDOS
# Adding data for LDOS
# Sleeping for 3
# Getting data for LEN
# Adding data for LEN
# Sleeping for 2
# Getting data for LLY
# Adding data for LLY
# Sleeping for 5
# Getting data for LNC
# Adding data for LNC
# Sleeping for 2
# Getting data for LIN
# Adding data for LIN
# Sleeping for 5
# Getting data for LKQ
# Adding data for LKQ
# Sleeping for 2
# Getting data for LMT
# Adding data for LMT
# Sleeping for 5
# Getting data for LOW
# Adding data for LOW
# Sleeping for 4
# Getting data for LYB
# Adding data for LYB
# Sleeping for 3
# Getting data for MTB
# Adding data for MTB
# Sleeping for 2
# Getting data for MAC
# Adding data for MAC
# Sleeping for 3
# Getting data for M
# Adding data for M
# Sleeping for 5
# Getting data for MRO
# Adding data for MRO
# Sleeping for 4
# Getting data for MPC
# Adding data for MPC
# Sleeping for 3
# Getting data for MKTX
# Adding data for MKTX
# Sleeping for 1
# Getting data for MAR
# Adding data for MAR
# Sleeping for 3
# Getting data for MMC
# Adding data for MMC
# Sleeping for 1
# Getting data for MLM
# Adding data for MLM
# Sleeping for 3
# Getting data for MAS
# Adding data for MAS
# Sleeping for 2
# Getting data for MA
# Adding data for MA
# Sleeping for 4
# Getting data for MKC
# Adding data for MKC
# Sleeping for 3
# Getting data for MXIM
# Adding data for MXIM
# Sleeping for 4
# Getting data for MCD
# Adding data for MCD
# Sleeping for 5
# Getting data for MCK
# Adding data for MCK
# Sleeping for 2
# Getting data for MDT
# Adding data for MDT
# Sleeping for 4
# Getting data for MRK
# Adding data for MRK
# Sleeping for 1
# Getting data for MET
# Adding data for MET
# Sleeping for 1
# Getting data for MTD
# Adding data for MTD
# Sleeping for 3
# Getting data for MGM
# Adding data for MGM
# Sleeping for 5
# Getting data for MCHP
# Adding data for MCHP
# Sleeping for 5
# Getting data for MU
# Adding data for MU
# Sleeping for 3
# Getting data for MSFT
# Adding data for MSFT
# Sleeping for 1
# Getting data for MAA
# Adding data for MAA
# Sleeping for 4
# Getting data for MHK
# Adding data for MHK
# Sleeping for 1
# Getting data for TAP
# Adding data for TAP
# Sleeping for 2
# Getting data for MDLZ
# Adding data for MDLZ
# Sleeping for 4
# Getting data for MNST
# Adding data for MNST
# Sleeping for 5
# Getting data for MCO
# Adding data for MCO
# Sleeping for 5
# Getting data for MS
# Adding data for MS
# Sleeping for 2
# Getting data for MOS
# Adding data for MOS
# Sleeping for 4
# Getting data for MSI
# Adding data for MSI
# Sleeping for 2
# Getting data for MSCI
# Adding data for MSCI
# Sleeping for 2
# Getting data for MYL
# Adding data for MYL
# Sleeping for 4
# Getting data for NDAQ
# Adding data for NDAQ
# Sleeping for 5
# Getting data for NOV
# Adding data for NOV
# Sleeping for 5
# Getting data for NKTR
# Adding data for NKTR
# Sleeping for 1
# Getting data for NTAP
# Adding data for NTAP
# Sleeping for 4
# Getting data for NFLX
# Adding data for NFLX
# Sleeping for 5
# Getting data for NWL
# Adding data for NWL
# Sleeping for 5
# Getting data for NEM
# Adding data for NEM
# Sleeping for 3
# Getting data for NWSA
# Adding data for NWSA
# Sleeping for 3
# Getting data for NWS
# Adding data for NWS
# Sleeping for 2
# Getting data for NEE
# Adding data for NEE
# Sleeping for 4
# Getting data for NLSN
# Adding data for NLSN
# Sleeping for 5
# Getting data for NKE
# Adding data for NKE
# Sleeping for 5
# Getting data for NI
# Adding data for NI
# Sleeping for 3
# Getting data for NBL
# Adding data for NBL
# Sleeping for 3
# Getting data for JWN
# Adding data for JWN
# Sleeping for 3
# Getting data for NSC
# Adding data for NSC
# Sleeping for 4
# Getting data for NTRS
# Adding data for NTRS
# Sleeping for 2
# Getting data for NOC
# Adding data for NOC
# Sleeping for 2
# Getting data for NCLH
# Adding data for NCLH
# Sleeping for 1
# Getting data for NRG
# Adding data for NRG
# Sleeping for 1
# Getting data for NUE
# Adding data for NUE
# Sleeping for 5
# Getting data for NVDA
# Adding data for NVDA
# Sleeping for 4
# Getting data for ORLY
# Adding data for ORLY
# Sleeping for 5
# Getting data for OXY
# Adding data for OXY
# Sleeping for 3
# Getting data for OMC
# Adding data for OMC
# Sleeping for 2
# Getting data for OKE
# Adding data for OKE
# Sleeping for 1
# Getting data for ORCL
# Adding data for ORCL
# Sleeping for 5
# Getting data for PCAR
# Adding data for PCAR
# Sleeping for 5
# Getting data for PKG
# Adding data for PKG
# Sleeping for 3
# Getting data for PH
# Adding data for PH
# Sleeping for 2
# Getting data for PAYX
# Adding data for PAYX
# Sleeping for 2
# Getting data for PYPL
# Adding data for PYPL
# Sleeping for 3
# Getting data for PNR
# Adding data for PNR
# Sleeping for 2
# Getting data for PBCT
# Adding data for PBCT
# Sleeping for 2
# Getting data for PEP
# Adding data for PEP
# Sleeping for 3
# Getting data for PKI
# Adding data for PKI
# Sleeping for 2
# Getting data for PRGO
# Adding data for PRGO
# Sleeping for 4
# Getting data for PFE
# Adding data for PFE
# Sleeping for 4
# Getting data for PM
# Adding data for PM
# Sleeping for 4
# Getting data for PSX
# Adding data for PSX
# Sleeping for 2
# Getting data for PNW
# Adding data for PNW
# Sleeping for 3
# Getting data for PXD
# Adding data for PXD
# Sleeping for 1
# Getting data for PNC
# Adding data for PNC
# Sleeping for 1
# Getting data for PPG
# Adding data for PPG
# Sleeping for 2
# Getting data for PPL
# Adding data for PPL
# Sleeping for 1
# Getting data for PFG
# Adding data for PFG
# Sleeping for 4
# Getting data for PG
# Adding data for PG
# Sleeping for 1
# Getting data for PGR
# Adding data for PGR
# Sleeping for 4
# Getting data for PLD
# Adding data for PLD
# Sleeping for 1
# Getting data for PRU
# Adding data for PRU
# Sleeping for 4
# Getting data for PEG
# Adding data for PEG
# Sleeping for 1
# Getting data for PSA
# Adding data for PSA
# Sleeping for 5
# Getting data for PHM
# Adding data for PHM
# Sleeping for 1
# Getting data for PVH
# Adding data for PVH
# Sleeping for 1
# Getting data for QRVO
# Adding data for QRVO
# Sleeping for 4
# Getting data for PWR
# Adding data for PWR
# Sleeping for 4
# Getting data for QCOM
# Adding data for QCOM
# Sleeping for 5
# Getting data for DGX
# Adding data for DGX
# Sleeping for 3
# Getting data for RL
# Adding data for RL
# Sleeping for 3
# Getting data for RJF
# Adding data for RJF
# Sleeping for 5
# Getting data for RTN
# Adding data for RTN
# Sleeping for 3
# Getting data for O
# Adding data for O
# Sleeping for 1
# Getting data for REG
# Adding data for REG
# Sleeping for 4
# Getting data for RF
# Adding data for RF
# Sleeping for 5
# Getting data for RSG
# Adding data for RSG
# Sleeping for 4
# Getting data for RMD
# Adding data for RMD
# Sleeping for 2
# Getting data for RHI
# Adding data for RHI
# Sleeping for 5
# Getting data for ROK
# Adding data for ROK
# Sleeping for 1
# Getting data for ROL
# Adding data for ROL
# Sleeping for 5
# Getting data for ROP
# Adding data for ROP
# Sleeping for 1
# Getting data for ROST
# Adding data for ROST
# Sleeping for 2
# Getting data for RCL
# Adding data for RCL
# Sleeping for 1
# Getting data for CRM
# Adding data for CRM
# Sleeping for 3
# Getting data for SBAC
# Adding data for SBAC
# Sleeping for 3
# Getting data for SLB
# Adding data for SLB
# Sleeping for 4
# Getting data for STX
# Adding data for STX
# Sleeping for 4
# Getting data for SEE
# Adding data for SEE
# Sleeping for 5
# Getting data for SRE
# Adding data for SRE
# Sleeping for 1
# Getting data for SHW
# Adding data for SHW
# Sleeping for 2
# Getting data for SPG
# Adding data for SPG
# Sleeping for 4
# Getting data for SWKS
# Adding data for SWKS
# Sleeping for 2
# Getting data for SLG
# Adding data for SLG
# Sleeping for 5
# Getting data for SNA
# Adding data for SNA
# Sleeping for 1
# Getting data for SO
# Adding data for SO
# Sleeping for 2
# Getting data for LUV
# Adding data for LUV
# Sleeping for 4
# Getting data for SPGI
# Adding data for SPGI
# Sleeping for 1
# Getting data for SWK
# Adding data for SWK
# Sleeping for 1
# Getting data for SBUX
# Adding data for SBUX
# Sleeping for 1
# Getting data for STT
# Adding data for STT
# Sleeping for 4
# Getting data for SYK
# Adding data for SYK
# Sleeping for 4
# Getting data for STI
# Adding data for STI
# Sleeping for 2
# Getting data for SIVB
# Adding data for SIVB
# Sleeping for 1
# Getting data for SYMC
# Adding data for SYMC
# Sleeping for 2
# Getting data for SYF
# Adding data for SYF
# Sleeping for 4
# Getting data for SNPS
# Adding data for SNPS
# Sleeping for 5
# Getting data for SYY
# Adding data for SYY
# Sleeping for 2
# Getting data for TMUS
# Adding data for TMUS
# Sleeping for 5
# Getting data for TROW
# Adding data for TROW
# Sleeping for 5
# Getting data for TTWO
# Adding data for TTWO
# Sleeping for 1
# Getting data for TPR
# Adding data for TPR
# Sleeping for 2
# Getting data for TGT
# Adding data for TGT
# Sleeping for 2
# Getting data for TEL
# Adding data for TEL
# Sleeping for 3
# Getting data for FTI
# Adding data for FTI
# Sleeping for 2
# Getting data for TFX
# Adding data for TFX
# Sleeping for 2
# Getting data for TXN
# Adding data for TXN
# Sleeping for 5
# Getting data for TXT
# Adding data for TXT
# Sleeping for 2
# Getting data for TMO
# Adding data for TMO
# Sleeping for 2
# Getting data for TIF
# Adding data for TIF
# Sleeping for 2
# Getting data for TWTR
# Adding data for TWTR
# Sleeping for 5
# Getting data for TJX
# Adding data for TJX
# Sleeping for 1
# Getting data for TMK
# Adding data for TMK
# Sleeping for 3
# Getting data for TSS
# Adding data for TSS
# Sleeping for 1
# Getting data for TSCO
# Adding data for TSCO
# Sleeping for 5
# Getting data for TDG
# Adding data for TDG
# Sleeping for 1
# Getting data for TRV
# Adding data for TRV
# Sleeping for 5
# Getting data for TRIP
# Adding data for TRIP
# Sleeping for 3
# Getting data for TSN
# Adding data for TSN
# Sleeping for 4
# Getting data for UDR
# Adding data for UDR
# Sleeping for 3
# Getting data for ULTA
# Adding data for ULTA
# Sleeping for 3
# Getting data for USB
# Adding data for USB
# Sleeping for 5
# Getting data for UAA
# Adding data for UAA
# Sleeping for 3
# Getting data for UA
# Adding data for UA
# Sleeping for 2
# Getting data for UNP
# Adding data for UNP
# Sleeping for 1
# Getting data for UAL
# Adding data for UAL
# Sleeping for 3
# Getting data for UNH
# Adding data for UNH
# Sleeping for 1
# Getting data for UPS
# Adding data for UPS
# Sleeping for 4
# Getting data for URI
# Adding data for URI
# Sleeping for 1
# Getting data for UTX
# Adding data for UTX
# Sleeping for 3
# Getting data for UHS
# Adding data for UHS
# Sleeping for 2
# Getting data for UNM
# Adding data for UNM
# Sleeping for 1
# Getting data for VFC
# Adding data for VFC
# Sleeping for 4
# Getting data for VLO
# Adding data for VLO
# Sleeping for 2
# Getting data for VAR
# Adding data for VAR
# Sleeping for 5
# Getting data for VTR
# Adding data for VTR
# Sleeping for 5
# Getting data for VRSN
# Adding data for VRSN
# Sleeping for 3
# Getting data for VRSK
# Adding data for VRSK
# Sleeping for 2
# Getting data for VZ
# Adding data for VZ
# Sleeping for 4
# Getting data for VRTX
# Adding data for VRTX
# Sleeping for 5
# Getting data for VIAB
# Adding data for VIAB
# Sleeping for 4
# Getting data for V
# Adding data for V
# Sleeping for 1
# Getting data for VNO
# Adding data for VNO
# Sleeping for 5
# Getting data for VMC
# Adding data for VMC
# Sleeping for 5
# Getting data for WAB
# Adding data for WAB
# Sleeping for 3
# Getting data for WMT
# Adding data for WMT
# Sleeping for 1
# Getting data for WBA
# Adding data for WBA
# Sleeping for 1
# Getting data for DIS
# Adding data for DIS
# Sleeping for 5
# Getting data for WM
# Adding data for WM
# Sleeping for 5
# Getting data for WAT
# Adding data for WAT
# Sleeping for 3
# Getting data for WEC
# Adding data for WEC
# Sleeping for 2
# Getting data for WCG
# Adding data for WCG
# Sleeping for 4
# Getting data for WFC
# Adding data for WFC
# Sleeping for 4
# Getting data for WELL
# Adding data for WELL
# Sleeping for 3
# Getting data for WDC
# Adding data for WDC
# Sleeping for 4
# Getting data for WU
# Adding data for WU
# Sleeping for 3
# Getting data for WRK
# Adding data for WRK
# Sleeping for 5
# Getting data for WY
# Adding data for WY
# Sleeping for 2
# Getting data for WHR
# Adding data for WHR
# Sleeping for 3
# Getting data for WMB
# Adding data for WMB
# Sleeping for 4
# Getting data for WLTW
# Adding data for WLTW
# Sleeping for 1
# Getting data for WYNN
# Adding data for WYNN
# Sleeping for 2
# Getting data for XEL
# Adding data for XEL
# Sleeping for 4
# Getting data for XRX
# Adding data for XRX
# Sleeping for 1
# Getting data for XYL
# Adding data for XYL
# Sleeping for 4
# Getting data for YUM
# Adding data for YUM
# Sleeping for 2
# Getting data for ZBH
# Adding data for ZBH
# Sleeping for 1
# Getting data for ZION
# Adding data for ZION
# Sleeping for 4
# Getting data for ZTS
# Adding data for ZTS
# Sleeping for 5
# Getting data for ^DJI
# Adding data for ^DJI
# Sleeping for 4
# Getting data for ^GSPC
# Adding data for ^GSPC
# Sleeping for 3
# Getting data for ^IXIC
# Adding data for ^IXIC
# Sleeping for 3
# Getting data for ^RUT
# Adding data for ^RUT
# Sleeping for 5
# Getting data for ^VIX
# Adding data for ^VIX
# Sleeping for 1
# Getting data for ^TNX
# Adding data for ^TNX
# Sleeping for 1
# Getting data for ^TYX
# Adding data for ^TYX
# Sleeping for 2
