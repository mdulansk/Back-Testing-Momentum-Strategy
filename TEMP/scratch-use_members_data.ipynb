# %%
import os
import pandas as pd
import numpy as np

HOME_DIR = os.path.expanduser('~/')
data_folder = f'{HOME_DIR}/Documents/Algo/Data'
ticker_folder = f'{data_folder}/Tickers/Nasdaq-100'
index_yearly_members = pd.read_csv(f'{ticker_folder}/nasdaq_yearly_members_2007-12-24_2023-03-12.csv', parse_dates=True, index_col=0)
end_date = '2023-03-12'

# %%
index_yearly_members.head()
index_yearly_members.shape[1]
# Out:
# 206

# %%
for date in index_yearly_members.index[400:500]:
    curr_tickers = (index_yearly_members.loc[:,index_yearly_members.loc[end_date] == True].loc[end_date]).index.values
    print(f'{date}\tTickers ({len(curr_tickers)}):\n{curr_tickers[15:25]}')
# Out:
# <class 'numpy.ndarray'>
# 2009-01-27 00:00:00	Tickers (101):
# ['AVGO' 'AZN' 'BIIB' 'BKNG' 'BKR' 'BMRN' 'CDNS' 'CHTR' 'CMCSA' 'COST']
# <class 'numpy.ndarray'>
# [1.84019443e-196]
# 2009-01-28 00:00:00	Tickers (101):
# ['AVGO' 'AZN' 'BIIB' 'BKNG' 'BKR' 'BMRN' 'CDNS' 'CHTR' 'CMCSA' 'COST']
# <class 'numpy.ndarray'>
# []
# 2009-01-29 00:00:00	Tickers (101):
# ['AVGO' 'AZN' 'BIIB' 'BKNG' 'BKR' 'BMRN' 'CDNS' 'CHTR' 'CMCSA' 'COST']
# <class 'numpy.ndarray'>
# []
# 2009-01-30 00:00:00	Tickers (101):
# ['AVGO' 'AZN' 'BIIB' 'BKNG' 'BKR' 'BMRN' 'CDNS' 'CHTR' 'CMCSA' 'COST']
# <class 'numpy.ndarray'>
# []
# 2009-01-31 00:00:00	Tickers (101):
# ['AVGO' 'AZN' 'BIIB' 'BKNG' 'BKR' 'BMRN' 'CDNS' 'CHTR' 'CMCSA' 'COST']
# <class 'numpy.ndarray'>
# []
# 2009-02-01 00:00:00	Tickers (101):
# ['AVGO' 'AZN' 'BIIB' 'BKNG' 'BKR' 'BMRN' 'CDNS' 'CHTR' 'CMCSA' 'COST']
# <class 'numpy.ndarray'>
# []
# 2009-02-02 00:00:00	Tickers (101):
# ['AVGO' 'AZN' 'BIIB' 'BKNG' 'BKR' 'BMRN' 'CDNS' 'CHTR' 'CMCSA' 'COST']
# ...
