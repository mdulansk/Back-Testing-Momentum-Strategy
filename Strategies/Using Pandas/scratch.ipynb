# %%
import os
import sys
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from pandas.tseries.offsets import MonthEnd, BDay, DateOffset
HOME_DIR = os.path.expanduser('~/')
sys.path.append(f"{HOME_DIR}/Documents/Algo/Stock Price DB/")
import StockPriceData as spd
host = 'rpi4'
cached_data = './cached_data'

# %%
tickers_df = pd.read_csv(f'{cached_data}/nasdaq100_tickers.csv')
tickers = tickers_df['Ticker'].to_list()

# %%
def get_price_data(tickers,start_date,end_date,refresh_data):
    if refresh_data == True:
        tickers_and_prices = {}
        for ticker in tickers[:]:
            tickers_and_prices[ticker] = spd.process_ticker(ticker,start_date,end_date)['Adj_Close']
            # This next line concatenates the series to the dataframe, but doesn't include the series name as the column name.
            #daily_prices = pd.concat([price_data, prices],names=[ticker])
        all_daily_prices_df = pd.concat(tickers_and_prices, axis=1)
        all_daily_prices_df.to_csv(f'{cached_data}/all_daily_prices.csv')
    else:
        all_daily_prices_df = pd.read_csv(f'{cached_data}/all_daily_prices.csv', index_col=['Date'], parse_dates=True)
    # Clean up price df by removing stocks which don't have data for entire period, then calculate daily an monthly returns
    daily_prices_df = all_daily_prices_df.copy()#.dropna(axis=1) # Drop any stocks that are missing values
    symbols_missing_start_data = (daily_prices_df.loc[:, daily_prices_df.iloc[0].isnull()]).columns
    daily_prices_df.drop(columns=symbols_missing_start_data,inplace=True)
    # Add column for cash option for when there are no positive returns 
    daily_prices_df['CASH'] = 0.0 # We set to 0 to simulate 0% return as alternative to other investments when they're negative
    daily_returns = (daily_prices_df.pct_change()+1)[1:] # Adding 1 allows us to take the product of returns. Can't use cumsum though.
    weekly_returns = daily_returns.resample('W').prod() # Need to subtract 1 to get actual % returns.
    monthly_returns = daily_returns.resample('M').prod() # Need to subtract 1 to get actual % returns.
    #benchmark_monthly_returns = monthly_returns.mean(axis=1) # Instead of using index as benchmark, use product of returns for all stocks in universe
    return(daily_prices_df,daily_returns,weekly_returns,monthly_returns)

# %%
#Single Stock
#daily_prices_df = spd.process_ticker('AAPL','2010-01-01','2020-01-01')['Adj_Close']
#daily_returns = (daily_prices_df.pct_change()+1)[1:]
#weekly_returns = daily_returns.resample('W').prod() # Need to subtract 1 to get actual % returns.
#monthly_returns = daily_returns.resample('M').prod() # Need to subtract 1 to get actual % returns.

# %%
#Multiple Stocks:
start_date = '2010-01-01'
end_date = '2020-01-01'
refresh_data = True #False
daily_prices_df,daily_returns,weekly_returns,monthly_returns = get_price_data(tickers,start_date,end_date,refresh_data)
# Out:
# Retrieving price data for ATVI from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ATVI (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ADBE from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ADBE (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ADP from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ADP (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ABNB from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ABNB (2023-02-17) >= required end date (2020-01-01).
# (0, 8)
# Retrieving price data for ALGN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ALGN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for GOOGL from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for GOOGL (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for GOOG from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for GOOG (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AMZN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AMZN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AMD from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AMD (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AEP from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AEP (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AMGN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AMGN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ADI from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ADI (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ANSS from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ANSS (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AAPL from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AAPL (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AMAT from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AMAT (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ASML from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ASML (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AZN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AZN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for TEAM from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for TEAM (2023-02-17) >= required end date (2020-01-01).
# (1022, 8)
# Retrieving price data for ADSK from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ADSK (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for BKR from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for BKR (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for BIIB from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for BIIB (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for BKNG from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for BKNG (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for AVGO from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for AVGO (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CDNS from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CDNS (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CHTR from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CHTR (2023-02-17) >= required end date (2020-01-01).
# (2515, 8)
# Retrieving price data for CTAS from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CTAS (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CSCO from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CSCO (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CTSH from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CTSH (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CMCSA from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CMCSA (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CEG from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CEG (2023-02-17) >= required end date (2020-01-01).
# (0, 8)
# Retrieving price data for CPRT from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CPRT (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CSGP from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CSGP (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for COST from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for COST (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for CRWD from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CRWD (2023-02-17) >= required end date (2020-01-01).
# (141, 8)
# Retrieving price data for CSX from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for CSX (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for DDOG from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for DDOG (2023-02-17) >= required end date (2020-01-01).
# (72, 8)
# Retrieving price data for DXCM from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for DXCM (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for FANG from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for FANG (2023-02-17) >= required end date (2020-01-01).
# (1815, 8)
# Retrieving price data for DLTR from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for DLTR (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for EBAY from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for EBAY (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for EA from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for EA (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ENPH from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ENPH (2023-02-17) >= required end date (2020-01-01).
# (1951, 8)
# Retrieving price data for EXC from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for EXC (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for FAST from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for FAST (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for FISV from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for FISV (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for FTNT from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for FTNT (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for GILD from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for GILD (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for GFS from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for GFS (2023-02-17) >= required end date (2020-01-01).
# (0, 8)
# Retrieving price data for HON from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for HON (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for IDXX from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for IDXX (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ILMN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ILMN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for INTC from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for INTC (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for INTU from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for INTU (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ISRG from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ISRG (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for JD from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for JD (2023-02-17) >= required end date (2020-01-01).
# (1413, 8)
# Retrieving price data for KDP from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for KDP (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for KLAC from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for KLAC (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for KHC from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for KHC (2023-02-17) >= required end date (2020-01-01).
# (1132, 8)
# Retrieving price data for LRCX from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for LRCX (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for LCID from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for LCID (2023-02-17) >= required end date (2020-01-01).
# (0, 8)
# Retrieving price data for LULU from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for LULU (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for MAR from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MAR (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for MRVL from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MRVL (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for MELI from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MELI (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for META from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for META (2023-02-17) >= required end date (2020-01-01).
# (1917, 8)
# Retrieving price data for MCHP from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MCHP (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for MU from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MU (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for MSFT from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MSFT (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for MRNA from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MRNA (2023-02-17) >= required end date (2020-01-01).
# (268, 8)
# Retrieving price data for MDLZ from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MDLZ (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for MNST from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for MNST (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for NFLX from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for NFLX (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for NVDA from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for NVDA (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for NXPI from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for NXPI (2023-02-17) >= required end date (2020-01-01).
# (2367, 8)
# Retrieving price data for ORLY from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ORLY (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ODFL from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ODFL (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for PCAR from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for PCAR (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for PANW from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for PANW (2023-02-17) >= required end date (2020-01-01).
# (1874, 8)
# Retrieving price data for PAYX from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for PAYX (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for PYPL from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for PYPL (2023-02-17) >= required end date (2020-01-01).
# (1132, 8)
# Retrieving price data for PDD from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for PDD (2023-02-17) >= required end date (2020-01-01).
# (361, 8)
# Retrieving price data for PEP from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for PEP (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for QCOM from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for QCOM (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for REGN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for REGN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for RIVN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for RIVN (2023-02-17) >= required end date (2020-01-01).
# (0, 8)
# Retrieving price data for ROST from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ROST (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for SGEN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for SGEN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for SIRI from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for SIRI (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for SBUX from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for SBUX (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for SNPS from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for SNPS (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for TMUS from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for TMUS (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for TSLA from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for TSLA (2023-02-17) >= required end date (2020-01-01).
# (2394, 8)
# Retrieving price data for TXN from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for TXN (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for VRSK from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for VRSK (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for VRTX from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for VRTX (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for WBA from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for WBA (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for WBD from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for WBD (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for WDAY from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for WDAY (2023-02-17) >= required end date (2020-01-01).
# (1815, 8)
# Retrieving price data for XEL from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for XEL (2023-02-17) >= required end date (2020-01-01).
# (2516, 8)
# Retrieving price data for ZM from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ZM (2023-02-17) >= required end date (2020-01-01).
# (178, 8)
# Retrieving price data for ZS from 2010-01-01 - 2020-01-01
# Connecting to DB on rpi4.
# Latest price data for ZS (2023-02-17) >= required end date (2020-01-01).
# (452, 8)

# %%
daily_prices_df.head(1)
# Out:
#              ATVI   ADBE    ADP  ALGN  GOOGL   GOOG  AMZN  AMD    AEP   AMGN  \
# Date
# 2010-01-04  10.02  37.09  27.49  18.5  15.68  15.61   6.7  9.7  21.14  43.27
#
#             ...  SBUX   SNPS   TMUS    TXN   VRSK   VRTX    WBA    WBD   XEL  \
# Date        ...
# 2010-01-04  ...  9.26  22.44  13.21  18.77  29.07  44.24  26.33  15.84  13.6
#
#             CASH
# Date
# 2010-01-04   0.0
#
# [1 rows x 79 columns]

# %%
#resample_period = 'M'
resample_period = 'W'
#period_returns = monthly_returns
period_returns = weekly_returns
period_count = 0

for date in period_returns.index[:]:
    print(f'\nPeriod end:\t  {date}')
    last_period_end = date # Date for beginning of following month. We should increment this by 1 so we don't overlap with the end of last monthly period
    period_start = last_period_end + DateOffset(days=1) # Increment next period start by one day to avoid overlap with prior period.
    #period_start = last_period_end + BDay(1)#, normalize=True) # Increment next period start by one day to avoid overlap with prior period.
    if resample_period == 'M':
        period_end = date+MonthEnd(1)# Date for end of following month
    elif resample_period == 'W':
        period_end = period_start+BDay(4)#, normalize=True)
    print(f'last_period_end:  {last_period_end}\tperiod_start:  {period_start}\tperiod_end:  {period_end}',flush=True)
    period_count += 1
if period_count != period_returns.shape[0]:
    print(f'Periods: {period_count} != period returns: {period_returns.shape[0]}')
else:
    print(f'Periods: {period_count} == period returns: {period_returns.shape[0]}')
# Out:
# Period end:	  2010-01-10 00:00:00
# last_period_end:  2010-01-10 00:00:00	period_start:  2010-01-11 00:00:00	period_end:  2010-01-15 00:00:00
#
# Period end:	  2010-01-17 00:00:00
# last_period_end:  2010-01-17 00:00:00	period_start:  2010-01-18 00:00:00	period_end:  2010-01-22 00:00:00
#
# Period end:	  2010-01-24 00:00:00
# last_period_end:  2010-01-24 00:00:00	period_start:  2010-01-25 00:00:00	period_end:  2010-01-29 00:00:00
#
# Period end:	  2010-01-31 00:00:00
# last_period_end:  2010-01-31 00:00:00	period_start:  2010-02-01 00:00:00	period_end:  2010-02-05 00:00:00
#
# Period end:	  2010-02-07 00:00:00
# last_period_end:  2010-02-07 00:00:00	period_start:  2010-02-08 00:00:00	period_end:  2010-02-12 00:00:00
#
# Period end:	  2010-02-14 00:00:00
# last_period_end:  2010-02-14 00:00:00	period_start:  2010-02-15 00:00:00	period_end:  2010-02-19 00:00:00
#
# Period end:	  2010-02-21 00:00:00
# last_period_end:  2010-02-21 00:00:00	period_start:  2010-02-22 00:00:00	period_end:  2010-02-26 00:00:00
#
# Period end:	  2010-02-28 00:00:00
# last_period_end:  2010-02-28 00:00:00	period_start:  2010-03-01 00:00:00	period_end:  2010-03-05 00:00:00
#
# Period end:	  2010-03-07 00:00:00
# last_period_end:  2010-03-07 00:00:00	period_start:  2010-03-08 00:00:00	period_end:  2010-03-12 00:00:00
#
# Period end:	  2010-03-14 00:00:00
# last_period_end:  2010-03-14 00:00:00	period_start:  2010-03-15 00:00:00	period_end:  2010-03-19 00:00:00
#
# Period end:	  2010-03-21 00:00:00
# last_period_end:  2010-03-21 00:00:00	period_start:  2010-03-22 00:00:00	period_end:  2010-03-26 00:00:00
#
# Period end:	  2010-03-28 00:00:00
# last_period_end:  2010-03-28 00:00:00	period_start:  2010-03-29 00:00:00	period_end:  2010-04-02 00:00:00
#
# Period end:	  2010-04-04 00:00:00
# last_period_end:  2010-04-04 00:00:00	period_start:  2010-04-05 00:00:00	period_end:  2010-04-09 00:00:00
#
# Period end:	  2010-04-11 00:00:00
# last_period_end:  2010-04-11 00:00:00	period_start:  2010-04-12 00:00:00	period_end:  2010-04-16 00:00:00
#
# Period end:	  2010-04-18 00:00:00
# last_period_end:  2010-04-18 00:00:00	period_start:  2010-04-19 00:00:00	period_end:  2010-04-23 00:00:00
#
# Period end:	  2010-04-25 00:00:00
# last_period_end:  2010-04-25 00:00:00	period_start:  2010-04-26 00:00:00	period_end:  2010-04-30 00:00:00
#
# Period end:	  2010-05-02 00:00:00
# last_period_end:  2010-05-02 00:00:00	period_start:  2010-05-03 00:00:00	period_end:  2010-05-07 00:00:00
#
# Period end:	  2010-05-09 00:00:00
# last_period_end:  2010-05-09 00:00:00	period_start:  2010-05-10 00:00:00	period_end:  2010-05-14 00:00:00
#
# Period end:	  2010-05-16 00:00:00
# last_period_end:  2010-05-16 00:00:00	period_start:  2010-05-17 00:00:00	period_end:  2010-05-21 00:00:00
#
# Period end:	  2010-05-23 00:00:00
# last_period_end:  2010-05-23 00:00:00	period_start:  2010-05-24 00:00:00	period_end:  2010-05-28 00:00:00
#
# Period end:	  2010-05-30 00:00:00
# last_period_end:  2010-05-30 00:00:00	period_start:  2010-05-31 00:00:00	period_end:  2010-06-04 00:00:00
#
# Period end:	  2010-06-06 00:00:00
# last_period_end:  2010-06-06 00:00:00	period_start:  2010-06-07 00:00:00	period_end:  2010-06-11 00:00:00
#
# Period end:	  2010-06-13 00:00:00
# last_period_end:  2010-06-13 00:00:00	period_start:  2010-06-14 00:00:00	period_end:  2010-06-18 00:00:00
#
# Period end:	  2010-06-20 00:00:00
# last_period_end:  2010-06-20 00:00:00	period_start:  2010-06-21 00:00:00	period_end:  2010-06-25 00:00:00
#
# Period end:	  2010-06-27 00:00:00
# last_period_end:  2010-06-27 00:00:00	period_start:  2010-06-28 00:00:00	period_end:  2010-07-02 00:00:00
#
# Period end:	  2010-07-04 00:00:00
# last_period_end:  2010-07-04 00:00:00	period_start:  2010-07-05 00:00:00	period_end:  2010-07-09 00:00:00
#
# Period end:	  2010-07-11 00:00:00
# last_period_end:  2010-07-11 00:00:00	period_start:  2010-07-12 00:00:00	period_end:  2010-07-16 00:00:00
#
# Period end:	  2010-07-18 00:00:00
# last_period_end:  2010-07-18 00:00:00	period_start:  2010-07-19 00:00:00	period_end:  2010-07-23 00:00:00
#
# Period end:	  2010-07-25 00:00:00
# last_period_end:  2010-07-25 00:00:00	period_start:  2010-07-26 00:00:00	period_end:  2010-07-30 00:00:00
#
# Period end:	  2010-08-01 00:00:00
# last_period_end:  2010-08-01 00:00:00	period_start:  2010-08-02 00:00:00	period_end:  2010-08-06 00:00:00
#
# Period end:	  2010-08-08 00:00:00
# last_period_end:  2010-08-08 00:00:00	period_start:  2010-08-09 00:00:00	period_end:  2010-08-13 00:00:00
#
# Period end:	  2010-08-15 00:00:00
# last_period_end:  2010-08-15 00:00:00	period_start:  2010-08-16 00:00:00	period_end:  2010-08-20 00:00:00
#
# Period end:	  2010-08-22 00:00:00
# last_period_end:  2010-08-22 00:00:00	period_start:  2010-08-23 00:00:00	period_end:  2010-08-27 00:00:00
#
# Period end:	  2010-08-29 00:00:00
# last_period_end:  2010-08-29 00:00:00	period_start:  2010-08-30 00:00:00	period_end:  2010-09-03 00:00:00
#
# Period end:	  2010-09-05 00:00:00
# last_period_end:  2010-09-05 00:00:00	period_start:  2010-09-06 00:00:00	period_end:  2010-09-10 00:00:00
#
# Period end:	  2010-09-12 00:00:00
# last_period_end:  2010-09-12 00:00:00	period_start:  2010-09-13 00:00:00	period_end:  2010-09-17 00:00:00
#
# Period end:	  2010-09-19 00:00:00
# last_period_end:  2010-09-19 00:00:00	period_start:  2010-09-20 00:00:00	period_end:  2010-09-24 00:00:00
#
# Period end:	  2010-09-26 00:00:00
# last_period_end:  2010-09-26 00:00:00	period_start:  2010-09-27 00:00:00	period_end:  2010-10-01 00:00:00
#
# Period end:	  2010-10-03 00:00:00
# last_period_end:  2010-10-03 00:00:00	period_start:  2010-10-04 00:00:00	period_end:  2010-10-08 00:00:00
#
# Period end:	  2010-10-10 00:00:00
# last_period_end:  2010-10-10 00:00:00	period_start:  2010-10-11 00:00:00	period_end:  2010-10-15 00:00:00
#
# Period end:	  2010-10-17 00:00:00
# last_period_end:  2010-10-17 00:00:00	period_start:  2010-10-18 00:00:00	period_end:  2010-10-22 00:00:00
#
# Period end:	  2010-10-24 00:00:00
# last_period_end:  2010-10-24 00:00:00	period_start:  2010-10-25 00:00:00	period_end:  2010-10-29 00:00:00
#
# Period end:	  2010-10-31 00:00:00
# last_period_end:  2010-10-31 00:00:00	period_start:  2010-11-01 00:00:00	period_end:  2010-11-05 00:00:00
#
# Period end:	  2010-11-07 00:00:00
# last_period_end:  2010-11-07 00:00:00	period_start:  2010-11-08 00:00:00	period_end:  2010-11-12 00:00:00
#
# Period end:	  2010-11-14 00:00:00
# last_period_end:  2010-11-14 00:00:00	period_start:  2010-11-15 00:00:00	period_end:  2010-11-19 00:00:00
#
# Period end:	  2010-11-21 00:00:00
# last_period_end:  2010-11-21 00:00:00	period_start:  2010-11-22 00:00:00	period_end:  2010-11-26 00:00:00
#
# Period end:	  2010-11-28 00:00:00
# last_period_end:  2010-11-28 00:00:00	period_start:  2010-11-29 00:00:00	period_end:  2010-12-03 00:00:00
#
# Period end:	  2010-12-05 00:00:00
# last_period_end:  2010-12-05 00:00:00	period_start:  2010-12-06 00:00:00	period_end:  2010-12-10 00:00:00
#
# Period end:	  2010-12-12 00:00:00
# last_period_end:  2010-12-12 00:00:00	period_start:  2010-12-13 00:00:00	period_end:  2010-12-17 00:00:00
#
# Period end:	  2010-12-19 00:00:00
# last_period_end:  2010-12-19 00:00:00	period_start:  2010-12-20 00:00:00	period_end:  2010-12-24 00:00:00
#
# Period end:	  2010-12-26 00:00:00
# last_period_end:  2010-12-26 00:00:00	period_start:  2010-12-27 00:00:00	period_end:  2010-12-31 00:00:00
#
# Period end:	  2011-01-02 00:00:00
# last_period_end:  2011-01-02 00:00:00	period_start:  2011-01-03 00:00:00	period_end:  2011-01-07 00:00:00
#
# Period end:	  2011-01-09 00:00:00
# last_period_end:  2011-01-09 00:00:00	period_start:  2011-01-10 00:00:00	period_end:  2011-01-14 00:00:00
#
# Period end:	  2011-01-16 00:00:00
# last_period_end:  2011-01-16 00:00:00	period_start:  2011-01-17 00:00:00	period_end:  2011-01-21 00:00:00
#
# Period end:	  2011-01-23 00:00:00
# last_period_end:  2011-01-23 00:00:00	period_start:  2011-01-24 00:00:00	period_end:  2011-01-28 00:00:00
#
# Period end:	  2011-01-30 00:00:00
# last_period_end:  2011-01-30 00:00:00	period_start:  2011-01-31 00:00:00	period_end:  2011-02-04 00:00:00
#
# Period end:	  2011-02-06 00:00:00
# last_period_end:  2011-02-06 00:00:00	period_start:  2011-02-07 00:00:00	period_end:  2011-02-11 00:00:00
#
# Period end:	  2011-02-13 00:00:00
# last_period_end:  2011-02-13 00:00:00	period_start:  2011-02-14 00:00:00	period_end:  2011-02-18 00:00:00
#
# Period end:	  2011-02-20 00:00:00
#
# Period end:	  2012-04-08 00:00:00
# last_period_end:  2012-04-08 00:00:00	period_start:  2012-04-09 00:00:00	period_end:  2012-04-13 00:00:00
#
# Period end:	  2012-04-15 00:00:00
# last_period_end:  2012-04-15 00:00:00	period_start:  2012-04-16 00:00:00	period_end:  2012-04-20 00:00:00
#
# Period end:	  2012-04-22 00:00:00
# last_period_end:  2012-04-22 00:00:00	period_start:  2012-04-23 00:00:00	period_end:  2012-04-27 00:00:00
#
# Period end:	  2012-04-29 00:00:00
# last_period_end:  2012-04-29 00:00:00	period_start:  2012-04-30 00:00:00	period_end:  2012-05-04 00:00:00
#
# Period end:	  2012-05-06 00:00:00
# last_period_end:  2012-05-06 00:00:00	period_start:  2012-05-07 00:00:00	period_end:  2012-05-11 00:00:00
#
# Period end:	  2012-05-13 00:00:00
# last_period_end:  2012-05-13 00:00:00	period_start:  2012-05-14 00:00:00	period_end:  2012-05-18 00:00:00
#
# Period end:	  2012-05-20 00:00:00
# last_period_end:  2012-05-20 00:00:00	period_start:  2012-05-21 00:00:00	period_end:  2012-05-25 00:00:00
#
# Period end:	  2012-05-27 00:00:00
# last_period_end:  2012-05-27 00:00:00	period_start:  2012-05-28 00:00:00	period_end:  2012-06-01 00:00:00
#
# Period end:	  2012-06-03 00:00:00
# last_period_end:  2012-06-03 00:00:00	period_start:  2012-06-04 00:00:00	period_end:  2012-06-08 00:00:00
#
# Period end:	  2012-06-10 00:00:00
# last_period_end:  2012-06-10 00:00:00	period_start:  2012-06-11 00:00:00	period_end:  2012-06-15 00:00:00
#
# Period end:	  2012-06-17 00:00:00
# last_period_end:  2012-06-17 00:00:00	period_start:  2012-06-18 00:00:00	period_end:  2012-06-22 00:00:00
#
# Period end:	  2012-06-24 00:00:00
# last_period_end:  2012-06-24 00:00:00	period_start:  2012-06-25 00:00:00	period_end:  2012-06-29 00:00:00
#
# Period end:	  2012-07-01 00:00:00
# last_period_end:  2012-07-01 00:00:00	period_start:  2012-07-02 00:00:00	period_end:  2012-07-06 00:00:00
#
# Period end:	  2012-07-08 00:00:00
# last_period_end:  2012-07-08 00:00:00	period_start:  2012-07-09 00:00:00	period_end:  2012-07-13 00:00:00
#
# Period end:	  2012-07-15 00:00:00
# last_period_end:  2012-07-15 00:00:00	period_start:  2012-07-16 00:00:00	period_end:  2012-07-20 00:00:00
#
# Period end:	  2012-07-22 00:00:00
# last_period_end:  2012-07-22 00:00:00	period_start:  2012-07-23 00:00:00	period_end:  2012-07-27 00:00:00
#
# Period end:	  2012-07-29 00:00:00
# last_period_end:  2012-07-29 00:00:00	period_start:  2012-07-30 00:00:00	period_end:  2012-08-03 00:00:00
#
# Period end:	  2012-08-05 00:00:00
# last_period_end:  2012-08-05 00:00:00	period_start:  2012-08-06 00:00:00	period_end:  2012-08-10 00:00:00
#
# Period end:	  2012-08-12 00:00:00
# last_period_end:  2012-08-12 00:00:00	period_start:  2012-08-13 00:00:00	period_end:  2012-08-17 00:00:00
#
# Period end:	  2012-08-19 00:00:00
# last_period_end:  2013-09-29 00:00:00	period_start:  2013-09-30 00:00:00	period_end:  2013-10-04 00:00:00
#
# Period end:	  2013-10-06 00:00:00
# last_period_end:  2013-10-06 00:00:00	period_start:  2013-10-07 00:00:00	period_end:  2013-10-11 00:00:00
#
# Period end:	  2013-10-13 00:00:00
# last_period_end:  2013-10-13 00:00:00	period_start:  2013-10-14 00:00:00	period_end:  2013-10-18 00:00:00
#
# Period end:	  2013-10-20 00:00:00
# last_period_end:  2013-10-20 00:00:00	period_start:  2013-10-21 00:00:00	period_end:  2013-10-25 00:00:00
#
# Period end:	  2013-10-27 00:00:00
# last_period_end:  2013-10-27 00:00:00	period_start:  2013-10-28 00:00:00	period_end:  2013-11-01 00:00:00
#
# Period end:	  2013-11-03 00:00:00
# last_period_end:  2013-11-03 00:00:00	period_start:  2013-11-04 00:00:00	period_end:  2013-11-08 00:00:00
#
# Period end:	  2013-11-10 00:00:00
# last_period_end:  2013-11-10 00:00:00	period_start:  2013-11-11 00:00:00	period_end:  2013-11-15 00:00:00
#
# Period end:	  2013-11-17 00:00:00
# last_period_end:  2013-11-17 00:00:00	period_start:  2013-11-18 00:00:00	period_end:  2013-11-22 00:00:00
#
# Period end:	  2013-11-24 00:00:00
# last_period_end:  2013-11-24 00:00:00	period_start:  2013-11-25 00:00:00	period_end:  2013-11-29 00:00:00
#
# Period end:	  2013-12-01 00:00:00
# last_period_end:  2013-12-01 00:00:00	period_start:  2013-12-02 00:00:00	period_end:  2013-12-06 00:00:00
#
# Period end:	  2013-12-08 00:00:00
# last_period_end:  2013-12-08 00:00:00	period_start:  2013-12-09 00:00:00	period_end:  2013-12-13 00:00:00
#
# Period end:	  2013-12-15 00:00:00
# last_period_end:  2013-12-15 00:00:00	period_start:  2013-12-16 00:00:00	period_end:  2013-12-20 00:00:00
#
# Period end:	  2013-12-22 00:00:00
# last_period_end:  2013-12-22 00:00:00	period_start:  2013-12-23 00:00:00	period_end:  2013-12-27 00:00:00
#
# Period end:	  2013-12-29 00:00:00
# last_period_end:  2013-12-29 00:00:00	period_start:  2013-12-30 00:00:00	period_end:  2014-01-03 00:00:00
#
# Period end:	  2014-01-05 00:00:00
# last_period_end:  2014-01-05 00:00:00	period_start:  2014-01-06 00:00:00	period_end:  2014-01-10 00:00:00
#
# Period end:	  2014-01-12 00:00:00
# last_period_end:  2014-01-12 00:00:00	period_start:  2014-01-13 00:00:00	period_end:  2014-01-17 00:00:00
#
# Period end:	  2014-01-19 00:00:00
# last_period_end:  2014-01-19 00:00:00	period_start:  2014-01-20 00:00:00	period_end:  2014-01-24 00:00:00
#
# Period end:	  2014-01-26 00:00:00
# last_period_end:  2014-01-26 00:00:00	period_start:  2014-01-27 00:00:00	period_end:  2014-01-31 00:00:00
#
# Period end:	  2014-02-02 00:00:00
# last_period_end:  2014-02-02 00:00:00	period_start:  2014-02-03 00:00:00	period_end:  2014-02-07 00:00:00
#
# Period end:	  2014-02-09 00:00:00
# last_period_end:  2014-02-09 00:00:00	period_start:  2014-02-10 00:00:00	period_end:  2014-02-14 00:00:00
#
# last_period_end:  2014-06-29 00:00:00	period_start:  2014-06-30 00:00:00	period_end:  2014-07-04 00:00:00
#
# Period end:	  2014-07-06 00:00:00
# last_period_end:  2014-07-06 00:00:00	period_start:  2014-07-07 00:00:00	period_end:  2014-07-11 00:00:00
#
# Period end:	  2014-07-13 00:00:00
# last_period_end:  2014-07-13 00:00:00	period_start:  2014-07-14 00:00:00	period_end:  2014-07-18 00:00:00
#
# Period end:	  2014-07-20 00:00:00
# last_period_end:  2014-07-20 00:00:00	period_start:  2014-07-21 00:00:00	period_end:  2014-07-25 00:00:00
#
# Period end:	  2014-07-27 00:00:00
# last_period_end:  2014-07-27 00:00:00	period_start:  2014-07-28 00:00:00	period_end:  2014-08-01 00:00:00
#
# Period end:	  2014-08-03 00:00:00
# last_period_end:  2014-08-03 00:00:00	period_start:  2014-08-04 00:00:00	period_end:  2014-08-08 00:00:00
#
# Period end:	  2014-08-10 00:00:00
# last_period_end:  2014-08-10 00:00:00	period_start:  2014-08-11 00:00:00	period_end:  2014-08-15 00:00:00
#
# Period end:	  2014-08-17 00:00:00
# last_period_end:  2014-08-17 00:00:00	period_start:  2014-08-18 00:00:00	period_end:  2014-08-22 00:00:00
#
# Period end:	  2014-08-24 00:00:00
# last_period_end:  2014-08-24 00:00:00	period_start:  2014-08-25 00:00:00	period_end:  2014-08-29 00:00:00
#
# Period end:	  2014-08-31 00:00:00
# last_period_end:  2014-08-31 00:00:00	period_start:  2014-09-01 00:00:00	period_end:  2014-09-05 00:00:00
#
# Period end:	  2014-09-07 00:00:00
# last_period_end:  2014-09-07 00:00:00	period_start:  2014-09-08 00:00:00	period_end:  2014-09-12 00:00:00
#
# Period end:	  2014-09-14 00:00:00
# last_period_end:  2014-09-14 00:00:00	period_start:  2014-09-15 00:00:00	period_end:  2014-09-19 00:00:00
#
# Period end:	  2014-09-21 00:00:00
# last_period_end:  2014-09-21 00:00:00	period_start:  2014-09-22 00:00:00	period_end:  2014-09-26 00:00:00
#
# Period end:	  2014-09-28 00:00:00
# last_period_end:  2014-09-28 00:00:00	period_start:  2014-09-29 00:00:00	period_end:  2014-10-03 00:00:00
#
# Period end:	  2014-10-05 00:00:00
# last_period_end:  2014-10-05 00:00:00	period_start:  2014-10-06 00:00:00	period_end:  2014-10-10 00:00:00
#
# Period end:	  2014-10-12 00:00:00
# last_period_end:  2014-10-12 00:00:00	period_start:  2014-10-13 00:00:00	period_end:  2014-10-17 00:00:00
#
# Period end:	  2014-10-19 00:00:00
# last_period_end:  2014-10-19 00:00:00	period_start:  2014-10-20 00:00:00	period_end:  2014-10-24 00:00:00
#
# Period end:	  2014-10-26 00:00:00
# last_period_end:  2014-10-26 00:00:00	period_start:  2014-10-27 00:00:00	period_end:  2014-10-31 00:00:00
#
# Period end:	  2014-11-02 00:00:00
# last_period_end:  2014-11-02 00:00:00	period_start:  2014-11-03 00:00:00	period_end:  2014-11-07 00:00:00
#
# Period end:	  2014-11-09 00:00:00
# last_period_end:  2014-11-09 00:00:00	period_start:  2014-11-10 00:00:00	period_end:  2014-11-14 00:00:00
# last_period_end:  2018-06-03 00:00:00	period_start:  2018-06-04 00:00:00	period_end:  2018-06-08 00:00:00
#
# Period end:	  2018-06-10 00:00:00
# last_period_end:  2018-06-10 00:00:00	period_start:  2018-06-11 00:00:00	period_end:  2018-06-15 00:00:00
#
# Period end:	  2018-06-17 00:00:00
# last_period_end:  2018-06-17 00:00:00	period_start:  2018-06-18 00:00:00	period_end:  2018-06-22 00:00:00
#
# Period end:	  2018-06-24 00:00:00
# last_period_end:  2018-06-24 00:00:00	period_start:  2018-06-25 00:00:00	period_end:  2018-06-29 00:00:00
#
# Period end:	  2018-07-01 00:00:00
# last_period_end:  2018-07-01 00:00:00	period_start:  2018-07-02 00:00:00	period_end:  2018-07-06 00:00:00
#
# Period end:	  2018-07-08 00:00:00
# last_period_end:  2018-07-08 00:00:00	period_start:  2018-07-09 00:00:00	period_end:  2018-07-13 00:00:00
#
# Period end:	  2018-07-15 00:00:00
# last_period_end:  2018-07-15 00:00:00	period_start:  2018-07-16 00:00:00	period_end:  2018-07-20 00:00:00
#
# Period end:	  2018-07-22 00:00:00
# last_period_end:  2018-07-22 00:00:00	period_start:  2018-07-23 00:00:00	period_end:  2018-07-27 00:00:00
#
# Period end:	  2018-07-29 00:00:00
# last_period_end:  2018-07-29 00:00:00	period_start:  2018-07-30 00:00:00	period_end:  2018-08-03 00:00:00
#
# Period end:	  2018-08-05 00:00:00
# last_period_end:  2018-08-05 00:00:00	period_start:  2018-08-06 00:00:00	period_end:  2018-08-10 00:00:00
#
# Period end:	  2018-08-12 00:00:00
# last_period_end:  2018-08-12 00:00:00	period_start:  2018-08-13 00:00:00	period_end:  2018-08-17 00:00:00
#
# Period end:	  2018-08-19 00:00:00
# last_period_end:  2018-08-19 00:00:00	period_start:  2018-08-20 00:00:00	period_end:  2018-08-24 00:00:00
#
# Period end:	  2018-08-26 00:00:00
# last_period_end:  2018-08-26 00:00:00	period_start:  2018-08-27 00:00:00	period_end:  2018-08-31 00:00:00
#
# Period end:	  2018-09-02 00:00:00
# last_period_end:  2018-09-02 00:00:00	period_start:  2018-09-03 00:00:00	period_end:  2018-09-07 00:00:00
#
# Period end:	  2018-09-09 00:00:00
# last_period_end:  2018-09-09 00:00:00	period_start:  2018-09-10 00:00:00	period_end:  2018-09-14 00:00:00
#
# Period end:	  2018-09-16 00:00:00
# last_period_end:  2018-09-16 00:00:00	period_start:  2018-09-17 00:00:00	period_end:  2018-09-21 00:00:00
#
# Period end:	  2018-09-23 00:00:00
# last_period_end:  2018-09-23 00:00:00	period_start:  2018-09-24 00:00:00	period_end:  2018-09-28 00:00:00
#
# Period end:	  2018-09-30 00:00:00
# last_period_end:  2018-09-30 00:00:00	period_start:  2018-10-01 00:00:00	period_end:  2018-10-05 00:00:00
#
# Period end:	  2018-10-07 00:00:00
# last_period_end:  2018-10-07 00:00:00	period_start:  2018-10-08 00:00:00	period_end:  2018-10-12 00:00:00
#
# Period end:	  2018-10-14 00:00:00
# last_period_end:  2018-10-14 00:00:00	period_start:  2018-10-15 00:00:00	period_end:  2018-10-19 00:00:00
#
# Period end:	  2019-07-21 00:00:00
# last_period_end:  2019-07-21 00:00:00	period_start:  2019-07-22 00:00:00	period_end:  2019-07-26 00:00:00
#
# Period end:	  2019-07-28 00:00:00
# last_period_end:  2019-07-28 00:00:00	period_start:  2019-07-29 00:00:00	period_end:  2019-08-02 00:00:00
#
# Period end:	  2019-08-04 00:00:00
# last_period_end:  2019-08-04 00:00:00	period_start:  2019-08-05 00:00:00	period_end:  2019-08-09 00:00:00
#
# Period end:	  2019-08-11 00:00:00
# last_period_end:  2019-08-11 00:00:00	period_start:  2019-08-12 00:00:00	period_end:  2019-08-16 00:00:00
#
# Period end:	  2019-08-18 00:00:00
# last_period_end:  2019-08-18 00:00:00	period_start:  2019-08-19 00:00:00	period_end:  2019-08-23 00:00:00
#
# Period end:	  2019-08-25 00:00:00
# last_period_end:  2019-08-25 00:00:00	period_start:  2019-08-26 00:00:00	period_end:  2019-08-30 00:00:00
#
# Period end:	  2019-09-01 00:00:00
# last_period_end:  2019-09-01 00:00:00	period_start:  2019-09-02 00:00:00	period_end:  2019-09-06 00:00:00
#
# Period end:	  2019-09-08 00:00:00
# last_period_end:  2019-09-08 00:00:00	period_start:  2019-09-09 00:00:00	period_end:  2019-09-13 00:00:00
#
# Period end:	  2019-09-15 00:00:00
# last_period_end:  2019-09-15 00:00:00	period_start:  2019-09-16 00:00:00	period_end:  2019-09-20 00:00:00
#
# Period end:	  2019-09-22 00:00:00
# last_period_end:  2019-09-22 00:00:00	period_start:  2019-09-23 00:00:00	period_end:  2019-09-27 00:00:00
#
# Period end:	  2019-09-29 00:00:00
# last_period_end:  2019-09-29 00:00:00	period_start:  2019-09-30 00:00:00	period_end:  2019-10-04 00:00:00
#
# Period end:	  2019-10-06 00:00:00
# last_period_end:  2019-10-06 00:00:00	period_start:  2019-10-07 00:00:00	period_end:  2019-10-11 00:00:00
#
# Period end:	  2019-10-13 00:00:00
# last_period_end:  2019-10-13 00:00:00	period_start:  2019-10-14 00:00:00	period_end:  2019-10-18 00:00:00
#
# Period end:	  2019-10-20 00:00:00
# last_period_end:  2019-10-20 00:00:00	period_start:  2019-10-21 00:00:00	period_end:  2019-10-25 00:00:00
#
# Period end:	  2019-10-27 00:00:00
# last_period_end:  2019-10-27 00:00:00	period_start:  2019-10-28 00:00:00	period_end:  2019-11-01 00:00:00
#
# Period end:	  2019-11-03 00:00:00
# last_period_end:  2019-11-03 00:00:00	period_start:  2019-11-04 00:00:00	period_end:  2019-11-08 00:00:00
#
# Period end:	  2019-11-10 00:00:00
# last_period_end:  2019-11-10 00:00:00	period_start:  2019-11-11 00:00:00	period_end:  2019-11-15 00:00:00
#
# Period end:	  2019-11-17 00:00:00
# last_period_end:  2019-11-17 00:00:00	period_start:  2019-11-18 00:00:00	period_end:  2019-11-22 00:00:00
#
# Period end:	  2019-11-24 00:00:00
# last_period_end:  2019-11-24 00:00:00	period_start:  2019-11-25 00:00:00	period_end:  2019-11-29 00:00:00
#
# Period end:	  2019-12-01 00:00:00
# last_period_end:  2019-12-01 00:00:00	period_start:  2019-12-02 00:00:00	period_end:  2019-12-06 00:00:00
#
# Period end:	  2019-12-08 00:00:00
# last_period_end:  2019-12-08 00:00:00	period_start:  2019-12-09 00:00:00	period_end:  2019-12-13 00:00:00
#
# Period end:	  2019-12-15 00:00:00
# last_period_end:  2019-12-15 00:00:00	period_start:  2019-12-16 00:00:00	period_end:  2019-12-20 00:00:00
#
# Period end:	  2019-12-22 00:00:00
# last_period_end:  2019-12-22 00:00:00	period_start:  2019-12-23 00:00:00	period_end:  2019-12-27 00:00:00
#
# Period end:	  2019-12-29 00:00:00
# last_period_end:  2019-12-29 00:00:00	period_start:  2019-12-30 00:00:00	period_end:  2020-01-03 00:00:00
#
# Period end:	  2020-01-05 00:00:00
# last_period_end:  2020-01-05 00:00:00	period_start:  2020-01-06 00:00:00	period_end:  2020-01-10 00:00:00
# Periods: 522 == period returns: 522

# %%
tickers = pd.Series(spd.get_tickers_from_db(host)[0], name='tickers')
tickers.to_csv('./ticker_list_orig.csv')

# %%
  
input_str = '21/01/24 11:04:19'
  
dt_object = datetime.strptime(
  input_str, '%d/%m/%y %H:%M:%S')
print("The type of the input date string now is: ", 
      type(dt_object))
  
print("The date is", dt_object)

# %%
future_date_after_2yrs = dt_object + \
                        timedelta(days = 730)
 
future_date_after_2days = dt_object + \
                         timedelta(days = 2)
 
# printing calculated future_dates
print('future_date_after_2yrs:', str(future_date_after_2yrs))
print('future_date_after_2days:', str(future_date_after_2days))

# %%
just_date =  datetime.date(future_date_after_2days)
print(just_date)

# %%
data_folder = '/home/lantro/Documents/Algo Trading/LEAN/data/yahoo/'
ticker = 'spy' #'spy' 'eurusd=x' 'BTC-USD'
warmup_period = 200 # Set this to the length of your longest indicator, i.e. if you calculate a 200 day ma, set it to 200
#df = yf.download(ticker, start='2022-03-17', interval='30m')
#df.to_csv(data_folder+ticker+'.csv')
df = pd.read_csv(f"{data_folder}{ticker}.csv", index_col=[0], parse_dates=True, skipinitialspace=True)
df.rename(columns = {'Close':'close'}, inplace = True)
start_date = '2015-01-01' #Start date for data
end_date = '2022-05-01'
#df = df.loc[start_date-warmup_period:end_date] #Change this so that we use the whole thing and use the start date to specify when we want to start trading so indicators have time to "warm up"

    #To be fair we should note the date when our signals have enough data so we don't exclude dates for B&H return
long_only = False

# %%
start_dt_object = datetime.strptime(
  start_date, '%Y-%m-%d').date()-timedelta(days = warmup_period)
print(start_dt_object)

# %%
my_dict = {'BIG':[1.2],'MED':[1.05],'BAD':[0],'AWFL':[np.nan]}
my_dict

# %%
my_df = pd.DataFrame(my_dict, columns=my_dict.keys())

# %%
my_df

# %%
top_10 = my_df.loc[0,:].nlargest(10).ge(1)#.index

# %%
top_10[top_10.ge(1)].index

# %%
def create_new_param_vals(current_val, pct):
    # Take in old value and create new min/max pair based on supplied percentage
    min_max = tuple([int(current_val * (1-pct)),int(current_val * (1+pct))])
    print(f'min_max: {min_max}')
    return(min_max)
create_new_param_vals(100, .5)
# Out:
# min_max: (50, 150)
# (50, 150)
